# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '/gdrive/MyDrive/스토리디언트/'
# Out:
# /gdrive/MyDrive/스토리디언트

# %%
# !echo "# 2021-1-Classification_4classes" >> README.md
# !git init
# !git config --global user.email "koreankiwi99@gmail.com"
# !git config --global user.name "koreankiwi99"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://koreankiwi99:bbobbo1227!@github.com/koreankiwi99/storidient_colab.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /gdrive/My Drive/스토리디언트/.git/
# [main 0dafd75] first commit
#  1 file changed, 1 insertion(+)
# Counting objects: 33, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (21/21), done.
# Writing objects: 100% (33/33), 2.35 KiB | 120.00 KiB/s, done.
# Total 33 (delta 9), reused 0 (delta 0)
# remote: Resolving deltas: 100% (9/9), done.
# To https://github.com/koreankiwi99/storidient_colab.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git remote rm origin
